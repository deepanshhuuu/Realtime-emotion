# %%
# When the predicted values are row-wise and true values are column-wise
import math
n = int(input("Enter the size of confusion matrix : "))
matrix = []
for i in range(n):
    a = []
    for j in range(n):
        a.append(float(input()))
    matrix.append(a)
for i in range(n):
    for j in range(n):
        print(matrix[i][j], end = " ")
    print()
tp = []
tn = []
fp = []
fn = []
for i in range(n):
    for j in range(n):
        if (i == j):
            tp.append(matrix[i][j])
        else:
            continue
print("tp : ", tp)  
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if ((i == k) or (j == k)):
                continue
            else:
                sum += matrix[i][j]
    tn.append(sum)
    k = k + 1;
print("tn : ", tn)
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if((i == k) and (j != i)):
                sum += matrix[i][j]
            else:
                continue
    fp.append(sum)
    k = k + 1;
print("fp : ", fp)
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if((j == k) and (j != i)):
                sum += matrix[i][j]
            else:
                continue
    fn.append(sum)
    k = k + 1;
print("fn : ", fn)
def accuracy(t_p, t_n, f_p, f_n):
    acc = (t_p + t_n)/(t_p + t_n + f_p + f_p)
    return acc
def precision(t_p, t_n, f_p, f_n):
    pre = (t_p)/(t_p + f_p)
    return pre
def recall(t_p, t_n, f_p, f_n):
    rec = (t_p)/(t_p + f_n)
    return rec
def specificity(t_p, t_n, f_p, f_n):
    spe = (t_n)/(f_p + t_n)
    return spe
def fpr(t_p, t_n, f_p, f_n):
    fpr = (f_p)/(f_p + t_n)
    return fpr
def fnr(t_p, t_n, f_p, f_n):
    fnr = (f_n)/(f_n + t_p)
    return fnr
def f1score(t_p, t_n, f_p, f_n):
    f1s = (2*t_p)/(2*t_p + f_p + f_n)
    return f1s
def matthews(t_p, t_n, f_p, f_n):
    mat = ((t_p*t_n) - (f_p*f_n))/(math.sqrt((t_p + f_p)*(t_p + f_n)*(t_n + f_p)*(t_n + f_n)))
    return mat
k = 0
print("------------------------------------------------------------------------")
while(k < n):
    print("Given below are the metrics for label : ", k)
    print("Accuracy is : ", accuracy(tp[k], tn[k], fp[k], fn[k]))
    print("Precision is : ", precision(tp[k], tn[k], fp[k], fn[k]))
    print("Recall is : ", recall(tp[k], tn[k], fp[k], fn[k]))
    print("F-1 score is : ", f1score(tp[k], tn[k], fp[k], fn[k]))
    print("Specificity is : ", specificity(tp[k], tn[k], fp[k], fn[k]))
    print("False positive rate is : ", fpr(tp[k], tn[k], fp[k], fn[k]))
    print("Matthews correlation coefficient : ", matthews(tp[k], tn[k], fp[k], fn[k]))
    print("False negative rate is : ", fnr(tp[k], tn[k], fp[k], fn[k]))
    print("------------------------------------------------------------------------")
    k = k + 1

# %%
# When the true values are row-wise and predicted values are column-wise
import math
n = int(input("Enter the size of confusion matrix : "))
matrix = []
for i in range(n):
    a = []
    for j in range(n):
        a.append(float(input()))
    matrix.append(a)
for i in range(n):
    for j in range(n):
        print(matrix[i][j], end = " ")
    print()
tp = []
tn = []
fp = []
fn = []
for i in range(n):
    for j in range(n):
        if (i == j):
            tp.append(matrix[i][j])
        else:
            continue
print("tp : ", tp)  
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if ((j == k) or (i == k)):
                continue
            else:
                sum += matrix[i][j]
    tn.append(sum)
    k = k + 1;
print("tn : ", tn)
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if((j == k) and (i != j)):
                sum += matrix[i][j]
            else:
                continue
    fp.append(sum)
    k = k + 1;
print("fp : ", fp)
k = 0
while(k < n):
    sum = 0
    for i in range(n):
        for j in range(n):
            if((i == k) and (i != j)):
                sum += matrix[i][j]
            else:
                continue
    fn.append(sum)
    k = k + 1;
print("fn : ", fn)
def accuracy(t_p, t_n, f_p, f_n):
    acc = (t_p + t_n)/(t_p + t_n + f_p + f_p)
    return acc
def precision(t_p, t_n, f_p, f_n):
    pre = (t_p)/(t_p + f_p)
    return pre
def recall(t_p, t_n, f_p, f_n):
    rec = (t_p)/(t_p + f_n)
    return rec
def specificity(t_p, t_n, f_p, f_n):
    spe = (t_n)/(f_p + t_n)
    return spe
def fpr(t_p, t_n, f_p, f_n):
    fpr = (f_p)/(f_p + t_n)
    return fpr
def fnr(t_p, t_n, f_p, f_n):
    fnr = (f_n)/(f_n + t_p)
    return fnr
def f1score(t_p, t_n, f_p, f_n):
    f1s = (2*t_p)/(2*t_p + f_p + f_n)
    return f1s
def matthews(t_p, t_n, f_p, f_n):
    mat = ((t_p*t_n) - (f_p*f_n))/(math.sqrt((t_p + f_p)*(t_p + f_n)*(t_n + f_p)*(t_n + f_n)))
    return mat
sum_total = 0.0
for i in range(n):
    for j in range(n):
        sum_total += matrix[i][j]
sum_tp = 0.0
for i in range(n):
    sum_tp += tp[i]
k = 0
print("------------------------------------------------------------------------")
print("-----------Overall Accuracy of the Model is : ",(sum_tp)/(sum_total),"------")
print("------------------------------------------------------------------------")
while(k < n):
    print("Given below are the metrics for label : ", k)
    print("Accuracy is : ", accuracy(tp[k], tn[k], fp[k], fn[k]))
    print("Precision is : ", precision(tp[k], tn[k], fp[k], fn[k]))
    print("Recall is : ", recall(tp[k], tn[k], fp[k], fn[k]))
    print("F-1 score is : ", f1score(tp[k], tn[k], fp[k], fn[k]))
    print("Specificity is : ", specificity(tp[k], tn[k], fp[k], fn[k]))
    print("False positive rate is : ", fpr(tp[k], tn[k], fp[k], fn[k]))
    print("Matthews correlation coefficient : ", matthews(tp[k], tn[k], fp[k], fn[k]))
    print("False negative rate is : ", fnr(tp[k], tn[k], fp[k], fn[k]))
    print("------------------------------------------------------------------------")
    k = k + 1  # FER CNN
# Out:
# Enter the size of confusion matrix : 7
# 0.61
# 0.02
# 0.11
# 0.04
# 0.13
# 0.01
# 0.08
# 0.22
# 0.65
# 0.04
# 0.03
# 0.02
# 0.02
# 0.02
# 0.09
# 0.01
# 0.56
# 0.03
# 0.17
# 0.05
# 0.09
# 0.01
# 0.00
# 0.02
# 0.91
# 0.02
# 0.01
# 0.03
# 0.05
# 0.01
# 0.11
# 0.05
# 0.61
# 0.01
# 0.16
# 0.02
# 0.00
# 0.08
# 0.05
# 0.02
# 0.81
# 0.02
# 0.04
# 0.01
# 0.05
# 0.05
# 0.13
# 0.01
# 0.71
# 0.61 0.02 0.11 0.04 0.13 0.01 0.08
# 0.22 0.65 0.04 0.03 0.02 0.02 0.02
# 0.09 0.01 0.56 0.03 0.17 0.05 0.09
# 0.01 0.0 0.02 0.91 0.02 0.01 0.03
# 0.05 0.01 0.11 0.05 0.61 0.01 0.16
# 0.02 0.0 0.08 0.05 0.02 0.81 0.02
# 0.04 0.01 0.05 0.05 0.13 0.01 0.71
# tp :  [0.61, 0.65, 0.56, 0.91, 0.61, 0.81, 0.71]
# tn :  [5.569999999999998, 5.949999999999997, 5.589999999999998, 5.749999999999998, 5.509999999999998, 5.889999999999999, 5.599999999999998]
# fp :  [0.43, 0.05, 0.41, 0.25, 0.49000000000000005, 0.10999999999999999, 0.4]
# ...
